# %% [markdown]
# <a href="https://colab.research.google.com/github/DIANA0803/AUTOMATIZACION-DIANA-DURAN/blob/main/AID-P2-T3-Ejercicios%20en%20python%20pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Escribir un programa que pregunte al usuario por las ventas de un rango de años y 
#muestre por pantalla una serie con los datos de las ventas indexada por los años,
#antes y después de aplicarles un descuento del 10%.

import pandas as pd

inicio_rang = int(input('Ingrese el año inicial: '))
fin_rang = int(input('Ingrese el año final: '))
ventas = {}
for i in range(inicio_rang, fin_rang+1):
    ventas[i] = float(input('Ingrese las ventas del anuales ' + str(i) +': '))
ventas = pd.Series(ventas)
print('Ventas\n', ventas)
print('Ventas con descuento\n', ventas*0.9)
# Out:
# Ingrese el año inicial: 2019
# Ingrese el año final: 2020
# Ingrese las ventas del anuales 2019: 1000
# Ingrese las ventas del anuales 2020: 3000
# Ventas
#  2019    1000.0
# 2020    3000.0
# dtype: float64
# Ventas con descuento
#  2019     900.0
# 2020    2700.0
# dtype: float64

# %%
#Escribir una función que reciba un diccionario con las notas de los alumnos en curso en un examen y devuelva una serie con la nota mínima, 
#la máxima, media y la desviación típica.

import pandas as pd

def diccionario_n(notas):
    notas = pd.Series(notas)
    #Formulas para realizar operaciones al diccionario
    estadisticos = pd.Series([notas.min(), notas.max(), 
                              notas.mean(), notas.std()], index=['Min', 'Max', 'Media', 'Desviación típica'])
    return estadisticos
#Generamos diccionario
notas = {'Santiago':8, 'Diana':10, 'Marcelo':7, 
         'Javier': 9, 'Andrea': 9.5}
print(diccionario_n(notas))
# Out:
# Min                   7.000000
# Max                  10.000000
# Media                 8.700000
# Desviación típica     1.204159
# dtype: float64

# %%
#Escribir una función que reciba un diccionario con las notas de los alumnos en curso en un examen y 
#devuelva una serie con las notas de los alumnos aprobados ordenadas de mayor a menor.

import pandas as pd

def diccionario_apro(notas):
    notas = pd.Series(notas)
    #Formula para aplicar mayor-menor 
    return notas[notas >= 5].sort_values(ascending=False)
#Generamos diccionario
notas = {'Santiago':8, 'Diana':10, 'Marcelo':7, 
         'Javier': 9.2, 'Andrea': 10}
print(diccionario_apro(notas))
# Out:
# Andrea      10.0
# Diana       10.0
# Javier       9.2
# Santiago     8.0
# Marcelo      7.0
# dtype: float64

# %%
#Escribir programa que genere y muestre por pantalla un DataFrame con los datos de la tabla siguiente:
#Mes      Ventas  Gastos 
#Enero    30500   22000
#Febrero  35600   23400
#Marzo    28300   18100
#Abril    33900   20700

import pandas as pd

diccionario_dat = {'Mes':['Enero', 'Febrero', 'Marzo', 'Abril'], 
                   'Ventas':[30500, 35600, 28300, 33900], 'Gastos':[22000, 23400, 18100, 20700]}
form = pd.DataFrame(diccionario_dat)
print(form)
# Out:
#        Mes  Ventas  Gastos
# 0    Enero   30500   22000
# 1  Febrero   35600   23400
# 2    Marzo   28300   18100
# 3    Abril   33900   20700

# %%
#Escribir una función que reciba un DataFrame con el formato del ejercicio anterior, una lista de meses, 
#y devuelva el balance (ventas - gastos) total en los meses indicados.

import pandas as pd

diccionario_dat = {'Mes':['Enero', 'Febrero', 'Marzo', 'Abril'], 
                   'Ventas':[30500, 35600, 28300, 33900], 
                   'Gastos':[22000, 23400, 18100, 20700]}

form = pd.DataFrame(diccionario_dat)

def balance(form, meses):
    form['Balance'] = form.Ventas - form.Gastos
    return form[form.Mes.isin(meses)].Balance.sum()

print(balance(form, ['Enero','Abril']))
# Out:
# 21700

# %%
#El fichero cotizacion.csv contiene las cotizaciones de las empresas del IBEX35 con las siguientes columnas: 
#nombre (nombre de la empresa), Final (precio de la acción al cierre de bolsa), Máximo (precio máximo de la acción durante la jornada), 
#Mínimo (precio mínimo de la acción durante la jornada), volumen (Volumen al cierre de bolsa), Efectivo (capitalización al cierre en miles de euros).
#Construir una función que construya un DataFrame a partir del un fichero con el formato anterior y 
#devuelva otro DataFrame con el mínimo, el máximo y la media de dada columna.

#formula para carga de archivos localales 
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-bee1336a-3dab-4f51-a9df-1919cbf8a93b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bee1336a-3dab-4f51-a9df-1919cbf8a93b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cotizacion 1.csv to cotizacion 1 (2).csv
# ...

# %%
import pandas as pd

def csv_coti(fichero):
    df = pd.read_csv(fichero, sep=';', 
                     decimal=',', thousands='.', index_col=0)
    return pd.DataFrame([df.min(), df.max(), 
                         df.mean()], index=['Mínimo', 'Máximo', 'Media'])

csv_coti('cotizacion 1.csv')
# Out:
#                Final        Máximo        Mínimo       Volumen    Efectivo
# Mínimo      1.016500      4.067500      1.016500  1.221000e+03    2343.090
# Máximo  19705.000000  19875.000000  19675.000000  3.612969e+07  145765.440
# Media    2796.768757   3170.113357   3136.510471  4.252279e+06   31767.778

# %%
import pandas as pd

#1. Generar un DataFrame con los datos del fichero.
titanic = pd.read_csv('https://raw.githubusercontent.com/DIANA0803/AUTOMATIZACION-DIANA-DURAN/main/titanic%201.csv', sep = ';')

titanic_2 = pd.concat([titanic])
titanic_2
# Out:
#     PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 0    1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/...
# 1    2,1,1,"Cumings, Mrs. John Bradley (Florence Br...
# 2    3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,S...
# 3    4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May ...
# 4    5,0,3,"Allen, Mr. William Henry",male,35,0,0,3...
# ..                                                 ...
# 886  887,0,2,"Montvila, Rev. Juozas",male,27,0,0,21...
# 887  888,1,1,"Graham, Miss. Margaret Edith",female,...
# 888  889,0,3,"Johnston, Miss. Catherine Helen ""Car...
# 889  890,1,1,"Behr, Mr. Karl Howell",male,26,0,0,11...
# 890  891,0,3,"Dooley, Mr. Patrick",male,32,0,0,3703...
#
# [891 rows x 1 columns]

# %%
#2. Mostrar por pantalla las dimensiones del DataFrame, el número de datos que contiene, los nombres de sus columnas y filas, los tipos de datos de las columnas, las 10 primeras filas y las 10 últimas filas.
print('Dimensiones:', titanic.shape)
print('Número de elemntos:', titanic.size)
print('Nombres de columnas:', titanic.columns)
print('Nombres de filas:', titanic.index)
print('Tipos de datos:\n', titanic.dtypes)
print('Primeras 10 filas:\n', titanic.head(10))
print('Últimas 10 filas:\n', titanic.tail(10))
# Out:
# Dimensiones: (891, 1)
# Número de elemntos: 891
# Nombres de columnas: Index(['PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked'], dtype='object')
# Nombres de filas: RangeIndex(start=0, stop=891, step=1)
# Tipos de datos:
#  PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked    object
# dtype: object
# Primeras 10 filas:
#    PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 0  1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/...
# 1  2,1,1,"Cumings, Mrs. John Bradley (Florence Br...
# 2  3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,S...
# 3  4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May ...
# 4  5,0,3,"Allen, Mr. William Henry",male,35,0,0,3...
# 5  6,0,3,"Moran, Mr. James",male,,0,0,330877,8.45...
# 6  7,0,1,"McCarthy, Mr. Timothy J",male,54,0,0,17...
# 7  8,0,3,"Palsson, Master. Gosta Leonard",male,2,...
# 8  9,1,3,"Johnson, Mrs. Oscar W (Elisabeth Vilhel...
# ...

# %%
#3. Mostrar por pantalla los datos del pasajero con identificador 148
print(titanic.loc[148])
# Out:
# PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked    149,0,2,"Navratil, Mr. Michel (""Louis M Hoffm...
# Name: 148, dtype: object

# %%
#4. Mostrar por pantalla las filas pares del DataFrame.
print(titanic.iloc[range(0,titanic.shape[0],2)])
# Out:
#     PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 0    1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/...
# 2    3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,S...
# 4    5,0,3,"Allen, Mr. William Henry",male,35,0,0,3...
# 6    7,0,1,"McCarthy, Mr. Timothy J",male,54,0,0,17...
# 8    9,1,3,"Johnson, Mrs. Oscar W (Elisabeth Vilhel...
# ..                                                 ...
# 882  883,0,3,"Dahlberg, Miss. Gerda Ulrika",female,...
# 884  885,0,3,"Sutehall, Mr. Henry Jr",male,25,0,0,S...
# 886  887,0,2,"Montvila, Rev. Juozas",male,27,0,0,21...
# 888  889,0,3,"Johnston, Miss. Catherine Helen ""Car...
# 890  891,0,3,"Dooley, Mr. Patrick",male,32,0,0,3703...
#
# [446 rows x 1 columns]

# %%
import pandas as pd
#5. Mostrar los nombres de las personas que iban en primera clase ordenadas alfabéticamente.
print(titanic[titanic["Pclass"]==1]['Name'].sort_values())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pclass'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-9f8459ec42a4> in <module>()
#       1 import pandas as pd
# ...

# %%
#6. Mostrar por pantalla el porcentaje de personas que sobrevivieron y murieron
print(titanic['Survived'].value_counts()/titanic['Survived'].count() * 100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Survived'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-eeb056735196> in <module>()
# ...

# %%
#7. Mostrar por pantalla el porcentaje de personas que sobrevivieron en cada clase
print(titanic.groupby('Pclass')['Survived'].value_counts(normalize=True))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-cef05d54b9f2> in <module>()
#       1 #7. Mostrar por pantalla el porcentaje de personas que sobrevivieron en cada clase
# ----> 2 print(titanic.groupby('Pclass')['Survived'].value_counts(normalize=True))
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6523             squeeze=squeeze,
#    6524             observed=observed,
# -> 6525             dropna=dropna,
#    6526         )
#    6527
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     531                 observed=observed,
#     532                 mutated=self.mutated,
# ...

# %%
#8. Eliminar del DataFrame los pasajeros con edad desconocida.
titanic.dropna(subset=['Age'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-92397245c938> in <module>()
#       1 #8. Eliminar del DataFrame los pasajeros con edad desconocida.
# ----> 2 titanic.dropna(subset=['Age'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5002             check = indices == -1
#    5003             if check.any():
# -> 5004                 raise KeyError(list(np.compress(check, subset)))
#    5005             agg_obj = self.take(indices, axis=agg_axis)
#    5006
#
# KeyError: ['Age']

# %%
#9. Mostrar la edad media de las mujeres que viajaban en cada clase.
print(titanic.groupby(['Pclass','Sex'])['Age'].mean().unstack()['female'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-5c84292cac99> in <module>()
#       1 #9. Mostrar la edad media de las mujeres que viajaban en cada clase.
# ----> 2 print(titanic.groupby(['Pclass','Sex'])['Age'].mean().unstack()['female'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6523             squeeze=squeeze,
#    6524             observed=observed,
# -> 6525             dropna=dropna,
#    6526         )
#    6527
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     531                 observed=observed,
#     532                 mutated=self.mutated,
# ...

# %%
#10. Añadir una nueva columna booleana para ver si el pasajero era menor de edad o no.
titanic['Young'] = titanic['Age'] < 18
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-b6a0c5d2d5f9> in <module>()
# ...

# %%
#11. Mostrar el porcentaje de menores y mayores de edad que sobrevivieron en cada clase.
print(titanic.groupby(['Pclass', 'Young'])['Survived'].value_counts(normalize = True) * 100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-4b1ad78efea2> in <module>()
#       1 #11. Mostrar el porcentaje de menores y mayores de edad que sobrevivieron en cada clase.
# ----> 2 print(titanic.groupby(['Pclass', 'Young'])['Survived'].value_counts(normalize = True) * 100)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6523             squeeze=squeeze,
#    6524             observed=observed,
# -> 6525             dropna=dropna,
#    6526         )
#    6527
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     531                 observed=observed,
# ...

# %%
#Los ficheros emisiones-2016.csv, emisiones-2017.csv, emisiones-2018.csvy emisiones-2019.csv, 
#contienen datos sobre las emisiones contaminates en la ciudad de Madrid en los años 
#2016, 2017, 2018 y 2019 respectivamente. Escribir un programa con los siguientes requisitos:


#formula para carga de archivos localales 
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b1f9630c-b549-44fa-bbd2-dec82a8e0937" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1f9630c-b549-44fa-bbd2-dec82a8e0937">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving emisiones-2017.csv to emisiones-2017.csv
# ...

# %%
import pandas as pd
import numpy as np
import datetime as dt

#1 Generar un DataFrame con los datos de los cuatro ficheros

csv_1 = pd.read_csv('https://raw.githubusercontent.com/DIANA0803/AUTOMATIZACION-DIANA-DURAN/main/emisiones-2016%201.csv', sep = ';')
csv_2 = pd.read_csv('https://raw.githubusercontent.com/DIANA0803/AUTOMATIZACION-DIANA-DURAN/main/emisiones-2017.csv', sep = ';')
csv_3 = pd.read_csv('https://raw.githubusercontent.com/DIANA0803/AUTOMATIZACION-DIANA-DURAN/main/emisiones-2018%201.csv', sep = ';')
csv_4 = pd.read_csv('https://raw.githubusercontent.com/DIANA0803/AUTOMATIZACION-DIANA-DURAN/main/emisiones-2019%201.csv', sep = ';')

emisiones = pd.concat([csv_1, csv_2, csv_3, csv_4])
emisiones
# Out:
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  ...    D30  V30   D31  V31
# 0            28         79         4         1  ...    9.0    V   9.0    V
# 1            28         79         4         1  ...    0.0    N   0.0    N
# 2            28         79         4         1  ...   10.0    V   8.0    V
# 3            28         79         4         1  ...    8.0    V   0.0    N
# 4            28         79         4         1  ...    7.0    V   7.0    V
# ...         ...        ...       ...       ...  ...    ...  ...   ...  ...
# 1831         28         79        60        14  ...  108.0    V  98.0    V
# 1832         28         79        60        14  ...   55.0    V   0.0    N
# 1833         28         79        60        14  ...   19.0    V  47.0    V
# 1834         28         79        60        14  ...   56.0    V   0.0    N
# 1835         28         79        60        14  ...    5.0    V   4.0    V
#
# [7266 rows x 69 columns]

# %%
#2. Filtrar las columnas del DataFrame para quedarse con las columnas ESTACION, MAGNITUD, AÑO, MES y las correspondientes a los días D01, D02, etc. 
columnas = ['ESTACION', 'MAGNITUD', 'ANO', 'MES']
columnas.extend([col for col in emisiones if col.startswith('D')])
emisiones = emisiones[columnas]
emisiones
# Out:
#       ESTACION  MAGNITUD   ANO  MES   D01  ...   D27   D28   D29    D30   D31
# 0            4         1  2016    1   8.0  ...   9.0   7.0   8.0    9.0   9.0
# 1            4         1  2016    2  12.0  ...   7.0   8.0   9.0    0.0   0.0
# 2            4         1  2016    3  11.0  ...   8.0   7.0   8.0   10.0   8.0
# 3            4         1  2016    4   8.0  ...   9.0   8.0   8.0    8.0   0.0
# 4            4         1  2016    5   7.0  ...   7.0   7.0   7.0    7.0   7.0
# ...        ...       ...   ...  ...   ...  ...   ...   ...   ...    ...   ...
# 1831        60        14  2019    8  94.0  ...  88.0  90.0  99.0  108.0  98.0
# 1832        60        14  2019    9  88.0  ...  54.0  68.0  70.0   55.0   0.0
# 1833        60        14  2019   10  44.0  ...  28.0  33.0  16.0   19.0  47.0
# 1834        60        14  2019   11  41.0  ...  55.0  52.0  47.0   56.0   0.0
# 1835        60        14  2019   12  47.0  ...  17.0  13.0  14.0    5.0   4.0
#
# [7266 rows x 35 columns]

# %%
#3. Reestructurar el DataFrame para que los valores de los contaminantes de las columnas de los días aparezcan en una única columna.
emisiones = emisiones.melt(id_vars=['ESTACION', 'MAGNITUD', 'ANO', 'MES'], var_name='DIA', value_name='VALOR')
emisiones
# Out:
#         ESTACION  MAGNITUD   ANO  MES  DIA  VALOR
# 0              4         1  2016    1  D01    8.0
# 1              4         1  2016    2  D01   12.0
# 2              4         1  2016    3  D01   11.0
# 3              4         1  2016    4  D01    8.0
# 4              4         1  2016    5  D01    7.0
# ...          ...       ...   ...  ...  ...    ...
# 225241        60        14  2019    8  D31   98.0
# 225242        60        14  2019    9  D31    0.0
# 225243        60        14  2019   10  D31   47.0
# 225244        60        14  2019   11  D31    0.0
# 225245        60        14  2019   12  D31    4.0
#
# [225246 rows x 6 columns]

# %%
#4.Añadir una columna con la fecha a partir de la concatenación del año, el mes y el día (usar el módulo datetime).
emisiones['DIA'] = emisiones.DIA.str.strip('D')
# Concatenamos las columnas del año, mes y día
emisiones['FECHA'] = emisiones.ANO.apply(str) + '/' + emisiones.MES.apply(str) + '/' + emisiones.DIA.apply(str)
# Convertimos la nueva columna al tipo fecha
emisiones['FECHA'] = pd.to_datetime(emisiones.FECHA, format='%Y/%m/%d', infer_datetime_format=True, errors='coerce')
emisiones
# Out:
#         ESTACION  MAGNITUD   ANO  MES DIA  VALOR      FECHA
# 0              4         1  2016    1  01    8.0 2016-01-01
# 1              4         1  2016    2  01   12.0 2016-02-01
# 2              4         1  2016    3  01   11.0 2016-03-01
# 3              4         1  2016    4  01    8.0 2016-04-01
# 4              4         1  2016    5  01    7.0 2016-05-01
# ...          ...       ...   ...  ...  ..    ...        ...
# 225241        60        14  2019    8  31   98.0 2019-08-31
# 225242        60        14  2019    9  31    0.0        NaT
# 225243        60        14  2019   10  31   47.0 2019-10-31
# 225244        60        14  2019   11  31    0.0        NaT
# 225245        60        14  2019   12  31    4.0 2019-12-31
#
# [225246 rows x 7 columns]

# %%
#5. Eliminar las filas con fechas no válidas (utilizar la función isnat del módulo numpy) y ordenar el DataFrame por estaciones, contaminantes y fecha.
emisiones = emisiones.drop(emisiones
                           [np.isnat(emisiones.FECHA)].index)
emisiones.sort_values(['ESTACION', 'MAGNITUD', 'FECHA'])
# Out:
#         ESTACION  MAGNITUD   ANO  MES DIA  VALOR      FECHA
# 0              4         1  2016    1  01    8.0 2016-01-01
# 7266           4         1  2016    1  02    7.0 2016-01-02
# 14532          4         1  2016    1  03    6.0 2016-01-03
# 21798          4         1  2016    1  04    6.0 2016-01-04
# 29064          4         1  2016    1  05    7.0 2016-01-05
# ...          ...       ...   ...  ...  ..    ...        ...
# 196181        60        14  2019   12  27   17.0 2019-12-27
# 203447        60        14  2019   12  28   13.0 2019-12-28
# 210713        60        14  2019   12  29   14.0 2019-12-29
# 217979        60        14  2019   12  30    5.0 2019-12-30
# 225245        60        14  2019   12  31    4.0 2019-12-31
#
# [221158 rows x 7 columns]

# %%
#6.Mostrar por pantalla las estaciones y los contaminantes disponibles en el DataFrame.

print('Estaciones:', emisiones.ESTACION.unique())
print('Contaminantes:', emisiones.MAGNITUD.unique())
# Out:
# Estaciones: [ 4  8 11 16 17 18 24 27 35 36 38 39 40 47 48 49 50 54 55 56 57 58 59 60]
# Contaminantes: [ 1  6  7  8 12  9 10 14 20 30 35 42 43 44]

# %%
#7. Crear una función que reciba una estación, un contaminante y un rango de fechas y devuelva una serie con las emisiones 
#del contaminante dado en la estación y rango de fechas dado.

def evolucion(estacion, contaminante, desde, hasta):
    return emisiones[(emisiones.ESTACION == estacion) & (emisiones.MAGNITUD == contaminante) 
    & (emisiones.FECHA >= desde) & (emisiones.FECHA <= hasta)].sort_values('FECHA').VALOR
evolucion(56, 8, dt.datetime.strptime('2018/10/25', '%Y/%m/%d'), 
          dt.datetime.strptime('2019/02/12', '%Y/%m/%d'))
# Out:
# 179559    89.0
# 186825    87.0
# 194091    46.0
# 201357    38.0
# 208623    29.0
#           ...
# 57841     82.0
# 65107     64.0
# 72373     26.0
# 79639     59.0
# 86905     71.0
# Name: VALOR, Length: 111, dtype: float64

# %%
#8. Mostrar un resumen descriptivo (mímino, máximo, media, etc) para cada contaminante.

emisiones.groupby('MAGNITUD').VALOR.describe()
# Out:
#             count       mean         std   min    25%    50%    75%       max
# MAGNITUD
# 1         14610.0   7.428953    7.012504  0.00   4.00   7.00  10.00    610.00
# 6         14610.0   0.350233    0.215935  0.00   0.20   0.30   0.40     14.90
# 7         35064.0  20.446412  135.123509  0.00   4.00   9.00  23.00  24742.00
# 8         35064.0  37.677618   20.118050  0.00  22.00  35.00  50.00    148.00
# 9          8948.0  10.087729   10.643591  0.00   6.00   9.00  13.00    850.00
# 10        17897.0  18.772923   35.723619  0.00  10.00  16.00  24.00   4481.00
# 12        35064.0  67.959417   61.443940  0.00  29.00  48.00  84.00   1005.00
# 14        20454.0  49.941772   24.753120  0.00  31.00  52.00  69.00    336.00
# 20         8766.0   2.364944    4.236706  0.00   0.80   1.60   2.80    195.00
# 30         8766.0   0.531371    0.538180  0.00   0.20   0.40   0.70     15.10
# 35         8766.0   0.479751    1.183618  0.00   0.10   0.20   0.50     35.70
# ...

# %%
#9. Mostrar un resumen descriptivo para cada contaminente por distritos.

emisiones.groupby(['ESTACION', 
                   'MAGNITUD']).VALOR.describe()
# Out:
#                     count       mean        std  min   25%   50%    75%    max
# ESTACION MAGNITUD
# 4        1         1461.0   7.329911  16.379050  1.0   4.0   7.0    9.0  610.0
#          6         1461.0   0.411499   0.172902  0.1   0.3   0.4    0.5    1.3
#          7         1461.0  31.939767  37.667968  0.0   8.0  16.0   42.0  239.0
#          8         1461.0  44.398357  17.766063  0.0  31.0  43.0   55.0  105.0
#          12        1461.0  93.341547  72.436531  0.0  44.0  69.0  119.0  467.0
# ...                   ...        ...        ...  ...   ...   ...    ...    ...
# 60       7         1461.0  12.326489  19.593109  1.0   2.0   4.0   12.0  151.0
#          8         1461.0  31.125941  18.101896  3.0  18.0  27.0   41.0  101.0
#          10        1461.0  17.033539  12.205022  1.0   9.0  14.0   21.0  215.0
#          12        1461.0  50.023956  45.933843  6.0  22.0  33.0   60.0  328.0
#          14        1461.0  60.718001  26.309952  4.0  42.0  65.0   81.0  119.0
#
# ...

# %%
#10. Crear una función que reciba una estación y un contaminante y devuelva un resumen descriptivo de las emisiones 
#del contaminante indicado en la estadión indicada.


def resumen(estacion, contaminante):
    return emisiones[(emisiones.ESTACION == estacion)
     & (emisiones.MAGNITUD == contaminante)].VALOR.describe()


print('Resumen Dióxido de Nitrógeno en Plaza Elíptica:\n'
, resumen(56, 8),'\n', sep='')
print('Resumen Dióxido de Nitrógeno en Plaza del Carmen:\n'
, resumen(35, 8), sep='')
# Out:
# Resumen Dióxido de Nitrógeno en Plaza Elíptica:
# count    1461.000000
# mean       55.113621
# std        21.911483
# min         0.000000
# 25%        39.000000
# 50%        53.000000
# 75%        69.000000
# max       142.000000
# Name: VALOR, dtype: float64
#
# Resumen Dióxido de Nitrógeno en Plaza del Carmen:
# count    1461.000000
# mean       43.260096
# std        16.384656
# min         0.000000
# 25%        32.000000
# 50%        43.000000
# 75%        54.000000
# max        96.000000
# Name: VALOR, dtype: float64

# %%
#11.Crear una función que devuelva las emisiones medias mensuales de un contaminante y un año dados para todos las estaciones.
def evolucion_mensual(contaminante, año):
    return emisiones[(emisiones.MAGNITUD == contaminante) & (emisiones.ANO == año)].groupby(['ESTACION', 'MES']).VALOR.mean().unstack('MES')

evolucion_mensual(8, 2018)
# Out:
# MES              1          2          3   ...         10         11         12
# ESTACION                                   ...
# 4         46.838710  48.285714  31.387097  ...  47.741935  42.833333  55.870968
# 8         66.612903  63.392857  48.774194  ...  58.193548  57.033333  69.193548
# 11        53.483871  50.178571  35.516129  ...  46.354839  45.700000  61.709677
# 16        51.612903  44.892857  32.387097  ...  38.387097  41.500000  54.483871
# 17        52.677419  49.785714  28.258065  ...  39.935484  37.766667  56.967742
# 18        47.419355  45.500000  24.838710  ...  38.387097  37.966667  52.612903
# 24        30.064516  28.142857  11.419355  ...  24.645161  22.966667  35.290323
# 27        49.677419  44.285714  28.225806  ...  38.096774  39.533333  54.580645
# 35        51.903226  58.535714  40.967742  ...  48.580645  36.766667  52.612903
# 36        53.161290  46.607143  31.354839  ...  40.290323  43.300000  59.032258
# ...

# %%
#12.Crear un función que reciba una estación de medición y devuelva un DataFrame con las medias mensuales de los distintos tipos de contaminantes.

def evolucion_mensual(contaminante, año):
    return emisiones[(emisiones.MAGNITUD == contaminante) & (emisiones.ANO == año)].groupby(['ESTACION', 'MAGNITUD']).VALOR.mean().unstack('MAGNITUD')

evolucion_mensual(8, 2018)
# Out:
# MAGNITUD          8
# ESTACION
# 4         42.936986
# 8         54.802740
# 11        42.783562
# 16        36.600000
# 17        36.704110
# 18        33.394521
# 24        19.635616
# 27        36.484932
# 35        43.772603
# 36        38.849315
# 38        41.542466
# 39        38.717808
# 40        36.838356
# 47        34.832877
# 48        38.953425
# 49        29.210959
# 50        39.698630
# 54        37.180822
# 55        41.156164
# 56        52.539726
# 57        31.441096
# 58        14.956164
# 59        25.424658
# 60        28.279452
